# %% [markdown]
# # Archivio Bonsanti
#
# After having separated from the full text (*L'ARCHIVIO DEGLI ARCHIVI*) the part regarding this specific archive, I then turned it into a .txt separately and modified with all the specific symbols expressed in the original dissertation.
#
# I then operated onto uploading it and then I split it through the ReGex *'\n'*, creating a list.
#
# At this point the list created gave me problem for the dataframe and to save it as CSV. So to simplify it I printed 'lines' and then copied in a list ('lists'). Here I manually also deleted all the categories ('quaderni 1' 'quaderni militari' etc), to leave just the units.
#
# I then went to extract to properly insert each unit in each appropriate series and then I extracted the year, month and date.
#
# Finally I saved it all as a CSV and Excel file.

# %%
import re
with open('archiviobonsanti.txt') as f:
  content = f.read()
import pandas as pd

from pandas import read_csv, Series



series = content.split('SERIE') # create a list
# series = [s for s in series if s] # remove empty strings
for serie in series:
  lines = serie.split("\n") # split lines by new line
  # lines = [l for l in lines if l] # remove empty strings
  serie_title = 'SERIE '+lines[0].strip()
  lines = lines[1:] # remove the title from the list of lines
  # print(serie_title, '\n', lines)
  for line in lines: 
    lines = line.split("''")# split line by empty element
    lines = [l for l in lines if l] # remove empty strings

    for line in lines:

      lines = line.strip().split("\n") #split line by new line 
      lines = [l for l in lines if l] # remove empty strings
      # at this point the list created gave me problem for the dataframe and to save it as csv
      # so to simplify it I printed 'lines' and then copied in a list ('lists')
      # here I manually also deleted all the categories ('quaderni 1' 'quaderni militari' etc)
      # to leave just the units
      lists = [['«Piccola antologia 1904»'],
         ['«1913. – Gaddus» [appunti di analisi matematica]'],
         ['«Giornale di campagna vol. 2°. 1915-1916»'],
         ['[Quaderno di studio del tedesco *10* novembre 1917]'],
         ['[Quaderno di studio del tedesco *24* aprile 1918-23 maggio 1918]'],
         ['[Quaderno di studio del tedesco «*28* Ottobre 1918»]'],
         ['«Lingua tedesca. 1918»'],
         ['[Quaderno di studio del tedesco] 1928'],
         ['[Quaderno di studio del tedesco] s.d.'],
         ['«Giornale finanziario 1920»'],
         ['Contabilità e appunti agosto 1921'],
         ['[Quaderno di contabilità gennaio 1923-gennaio 1924; 2 pz]'],
         ['«Note finanziarie e di viaggio. 1924»'],
         ['«Oeconomicum. 1925»'],
         ['«Oeconomicum. Anno 1926»'],
         ['«1922. | Notes. | Riscaldamento centrale.»'],
         ['[Quaderno di lavoro 1 1922]'],
         ['[Quaderno di lavoro 2 1922]'],
         ['[Quaderno di lavoro 3 1922]'],
         ['[Quaderno di lavoro *4* marzo 1922]'],
         ['[Quaderno di lavoro *5* maggio 1922]'],
         ['[Quaderno di appunti tecnici «*19* aprile 1922»]'],
         ['[Quaderno tecnico. Ottobre 1922]'],
         ['«1923. Indirizzi, telefoni, referenze, ecc.»'],
         ['«1924. Programma di un viaggio in Francia.» e [appunti universitari 1924]'],
         ['«Note filosofiche 1924»'],
         ['«Sunti di Pedagogia settembre 1924»'],
         ['«I “Canti” di Leopardi 1924»'],
         ['[Quaderno Leopardi 1924]'],
         ['[Appunti universitari. 1924-1925]'],
         ['«Brevi appunti presi alle lezioni di filosofia 1925»'],
         ['«Schemi per la preparazione in filosofia 1925».'],
         ['«1924. Trigonometria»'],
         ['«Lezioni di algebra 1924»'],
         ['«Lezioni di algebra 1924-1925»'],
         ['[Lezioni di algebra 1924-1925]'],
         ['«Lezioni di trigonometria piana 1924»'],
         ['[Quaderno di matematica a.s. 1924-1925]'],
         ['Risoluzione di triangoli [a.s. 1924-1925]'],
         ['[Quaderno di matematica a.s. 1924-1925]'],
         ['«Formule mnemoniche [a.s. 1924-1925]»'],
         ['Agenda vuota'],
         ['Disegni tecnici'],
         ['Tavole'],
         ['Prose'],
         ['Appunti'],
         ['Appunti 1-4 [ordine cronologico]'],
         ['Appunti senza data 1, 2'],
         ['Appunti non autografi']]
      
# I combined the lists to obtain a single one.

combined_list = []

for sublist in lists:
    combined_list.extend(sublist)
df = pd.DataFrame(combined_list, columns=['titolo']) # I created the dataframe with a single column title where I put all the units

# here you can find some controlled lists that where then used to porperly populate the drataframe.

serie_1 = ['Quaderni 1 (1 scatola)', 'Appunti giovanili, scolastici e universitari (politecnico)', '«Piccola antologia 1904»', '«1913. – Gaddus» [appunti di analisi matematica]', '', 'Quaderni militari', '«Giornale di campagna vol. 2°. 1915-1916»', 'Quaderni di studio del tedesco', '[Quaderno di studio del tedesco 10 novembre 1917]', '[Quaderno di studio del tedesco 24 aprile 1918-23 maggio 1918]', '[Quaderno di studio del tedesco «28 Ottobre 1918»]', '«Lingua tedesca. 1918»', '[Quaderno di studio del tedesco] 1928', '[Quaderno di studio del tedesco] s.d.', '', 'Quaderni di contabilità', '«Giornale finanziario 1920»', 'Contabilità e appunti agosto 1921', '[Quaderno di contabilità gennaio 1923-gennaio 1924; 2 pz]', '«Note finanziarie e di viaggio. 1924»', '«Oeconomicum. 1925»', '«Oeconomicum. Anno 1926»', '', 'Quaderni 2 (1 scatola)', '', 'Quaderni di lavoro', '«1922. | Notes. | Riscaldamento centrale.»', '[Quaderno di lavoro 1 1922]', '[Quaderno di lavoro 2 1922]', '[Quaderno di lavoro 3 1922]', '[Quaderno di lavoro 4 marzo 1922]', '[Quaderno di lavoro 5 maggio 1922]', '[Quaderno di appunti tecnici «19-4-1922»]', '[Quaderno tecnico. Ottobre 1922]', '«1923. Indirizzi, telefoni, referenze, ecc.»', '', 'Quaderni 3 (1 scatola)', '', 'Quaderni dell’Accademia di Scienze e Lettere', '«1924. Programma di un viaggio in Francia.» e [appunti universitari 1924]', '«Note filosofiche 1924»', '«Sunti di Pedagogia settembre 1924»', '«I “Canti” di Leopardi 1924»', '[Quaderno Leopardi 1924]', '[Appunti universitari. 1924-1925]', '«Brevi appunti presi alle lezioni di filosofia 1925»', '«Schemi per la preparazione in filosofia 1925».', '', 'Quaderni del Liceo Parini 1924-1925', '«1924. Trigonometria»', '«Lezioni di algebra 1924»', '«Lezioni di algebra 1924-1925»', '[Lezioni di algebra 1924-1925]', '«Lezioni di trigonometria piana 1924»', '[Quaderno di matematica a.s. 1924-1925]', 'Risoluzione di triangoli [a.s. 1924-1925]', '[Quaderno di matematica a.s. 1924-1925]', '«Formule mnemoniche [a.s. 1924-1925]»', '', 'Agenda vuota', '', 'Disegni', 'Disegni tecnici', 'Tavole', '', '']
serie_1 = [l for l in serie_1 if l]
serie_2 = ['Testi, appunti (1 scatola)', 'Prose', 'Appunti', 'Appunti 1-4 [ordine cronologico]', 'Appunti senza data 1, 2', 'Appunti non autografi', '']
serie_2 = [l for l in serie_2 if l]
quaderni_1 = ["Appunti giovanili, scolastici e universitari (politecnico)", "«Piccola antologia 1904»", "«1913. – Gaddus» [appunti di analisi matematica]", "Quaderni militari", "«Giornale di campagna vol. 2°. 1915-1916»", "Quaderni di studio del tedesco", "[Quaderno di studio del tedesco 10 novembre 1917]", "[Quaderno di studio del tedesco 24 aprile 1918-23 maggio 1918]", "[Quaderno di studio del tedesco «28 Ottobre 1918»]", "«Lingua tedesca. 1918»", "[Quaderno di studio del tedesco] 1928", "[Quaderno di studio del tedesco] s.d.", "Quaderni di contabilità", "«Giornale finanziario 1920»", "Contabilità e appunti agosto 1921", "[Quaderno di contabilità gennaio 1923-gennaio 1924; 2 pz]","«Note finanziarie e di viaggio. 1924»", "«Oeconomicum. 1925»", "«Oeconomicum. Anno 1926»"]
quaderni_2 = ["Quaderni di lavoro", "«1922. | Notes. | Riscaldamento centrale.»", "[Quaderno di lavoro 1 1922]", "[Quaderno di lavoro 2 1922]", "[Quaderno di lavoro 3 1922]", "[Quaderno di lavoro 4 marzo 1922]", "[Quaderno di lavoro 5 maggio 1922]", "[Quaderno di appunti tecnici «19-4-1922»]", "[Quaderno tecnico. Ottobre 1922]", "«1923. Indirizzi, telefoni, referenze, ecc.»"]
quaderni_3 = ["Quaderni dell’Accademia di Scienze e Lettere","«1924. Programma di un viaggio in Francia.» e [appunti universitari 1924]", "«Note filosofiche 1924»","«Sunti di Pedagogia settembre 1924»", "«I “Canti” di Leopardi 1924»", "[Quaderno Leopardi 1924]", "[Appunti universitari. 1924-1925]", "«Brevi appunti presi alle lezioni di filosofia 1925»","«Schemi per la preparazione in filosofia 1925».", "Quaderni del Liceo Parini 1924-1925", "«1924. Trigonometria»", "«Lezioni di algebra 1924»", "«Lezioni di algebra 1924-1925»", "[Lezioni di algebra 1924-1925]", "«Lezioni di trigonometria piana 1924»", "[Quaderno di matematica a.s. 1924-1925]", "Risoluzione di triangoli [a.s. 1924-1925]", "[Quaderno di matematica a.s. 1924-1925]", "«Formule mnemoniche [a.s. 1924-1925]»", "Agenda vuota", "Disegni", "Disegni tecnici", "Tavole"]
testi_appunti = ['Prose', 'Appunti', 'Appunti 1-4 [ordine cronologico]', 'Appunti senza data 1, 2', 'Appunti non autografi']
app_giov = ["«Piccola antologia 1904»","«1913. – Gaddus» [appunti di analisi matematica]"]
quaderni_mi =["«Giornale di campagna vol. 2°. 1915-1916»"]
quaderni_ted = ["[Quaderno di studio del tedesco 10 novembre 1917]","[Quaderno di studio del tedesco 24 aprile 1918-23 maggio 1918]", "[Quaderno di studio del tedesco «28 Ottobre 1918»]", "«Lingua tedesca. 1918»", "[Quaderno di studio del tedesco] 1928", "[Quaderno di studio del tedesco] s.d."]
quaderni_cont= ["«Giornale finanziario 1920»", "Contabilità e appunti agosto 1921", "[Quaderno di contabilità gennaio 1923-gennaio 1924; 2 pz]", "«Note finanziarie e di viaggio. 1924»", "«Oeconomicum. 1925»", "«Oeconomicum. Anno 1926»"]
quaderni_lav = ["«1922. | Notes. | Riscaldamento centrale.»", "[Quaderno di lavoro 1 1922]","[Quaderno di lavoro 2 1922]", "[Quaderno di lavoro 3 1922]","[Quaderno di lavoro 4 marzo 1922]", "[Quaderno di lavoro 5 maggio 1922]", "[Quaderno di appunti tecnici «19-4-1922»]", "[Quaderno tecnico. Ottobre 1922]", "«1923. Indirizzi, telefoni, referenze, ecc.»"]
quaderni_ac = ["«1924. Programma di un viaggio in Francia.» e [appunti universitari 1924]","«Note filosofiche 1924»","«Sunti di Pedagogia settembre 1924»", "«I “Canti” di Leopardi 1924»", "[Quaderno Leopardi 1924]", "[Appunti universitari. 1924-1925]","«Brevi appunti presi alle lezioni di filosofia 1925»", "«Schemi per la preparazione in filosofia 1925»."]
quaderni_par = ["«1924. Trigonometria»", "«Lezioni di algebra 1924»", "«Lezioni di algebra 1924-1925»","[Lezioni di algebra 1924-1925]", "«Lezioni di trigonometria piana 1924»","[Quaderno di matematica a.s. 1924-1925]", "Risoluzione di triangoli [a.s. 1924-1925]", "[Quaderno di matematica a.s. 1924-1925]","«Formule mnemoniche [a.s. 1924-1925]»"]
agenda = []
disegni = ["Disegni tecnici", "Tavole"]

# the following code checked whether the element in the column title was in the specific list.

is_present=df["titolo"].isin(serie_1)
is_present_2=df["titolo"].isin(serie_2)
is_present_quad1=df["titolo"].isin(quaderni_1)
is_present_quad2=df["titolo"].isin(quaderni_2)
is_present_quad3=df["titolo"].isin(quaderni_3)
is_present_quad4=df["titolo"].isin(testi_appunti)
is_present_quadapp=df["titolo"].isin(app_giov)
is_present_quadmi=df["titolo"].isin(quaderni_mi)
is_present_quadted=df["titolo"].isin(quaderni_ted)
is_present_quadcon=df["titolo"].isin(quaderni_cont)
is_present_quadlav=df["titolo"].isin(quaderni_lav)
is_present_quadac=df["titolo"].isin(quaderni_ac)
is_present_quadpar=df["titolo"].isin(quaderni_par)
is_present_quadagenda=df["titolo"].isin(agenda)
is_present_quaddis=df["titolo"].isin(disegni)

# I then created the new columns that would be populated

df['serie'] = ''
df['sottoserie'] = ''
df['opera'] = ''

# finally I populated the columns with the condition of whether a certain unit was present in the controlled lists.

df.loc[is_present, 'serie'] = 'II 1'
df.loc[is_present_2, 'serie'] = 'II 2'
df.loc[is_present_quad1, 'sottoserie'] = 'Quaderni 1'
df.loc[is_present_quad2, 'sottoserie'] = 'Quaderni 2'
df.loc[is_present_quad3, 'sottoserie'] = 'Quaderni 3'
df.loc[is_present_quad4, 'sottoserie'] = 'Testi e Appunti'
df.loc[is_present_quadapp, 'opera'] = 'Appunti giovanili, scolastici e universitari (politecnico)'
df.loc[is_present_quadmi, 'opera'] = 'Quaderni militari'
df.loc[is_present_quadted, 'opera'] = 'Quaderni di studio del tedesco'
df.loc[is_present_quadcon, 'opera'] = 'Quaderni di contabilità'
df.loc[is_present_quadlav, 'opera'] = 'Quaderni di lavoro'
df.loc[is_present_quadac, 'opera'] = 'Quaderni dell’Accademia di Scienze e Lettere'
df.loc[is_present_quadpar, 'opera'] = 'Quaderni del Liceo Parini 1924-1925'
df.loc[is_present_quadagenda, 'opera'] = 'Agenda vuota'
df.loc[is_present_quaddis, 'opera'] = 'Disegni'

# I inserted a specific column that specified the archive

df.insert(0, 'archivio', 'Archivio Bonsanti')

# I created an id for all the units

df_list_id = []
for idx, row in df.iterrows():
    df_list_id.append("unitàbonsanti-" + str(idx))
df.insert(0, "unitàId", Series(df_list_id, dtype="string"))

# I inserted another columns specifying the container 

df.insert(5, 'contenitore', '1 scatola')

# finally I saved the table both in csv and excel
pattern = r"\b(\d{4}(?:-\d{4})?)\b"
extracted_dates = df['titolo'].str.extract(pattern)

df["anno"]=extracted_dates
pattern_month=r"(?i)\b(?:gennaio|febbraio|marzo|aprile|maggio|giugno|luglio|agosto|settembe|ottobre|novembre|dicembre)\b"
df['mese'] = df['titolo'].str.extract(f'({pattern_month})', expand=False)
pattern_day=r'\*\d{1,2}\*'
df['day'] = df['titolo'].str.extract(f'({pattern_day})', expand=False)


df.to_csv("bonsantiprova.csv")
df.to_excel('bonsantiprova.xlsx', index = False)
