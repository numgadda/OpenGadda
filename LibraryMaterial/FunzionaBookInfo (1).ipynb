# %%
#CODICE FUNZIONA PER DIVIDERE LE COLONNE E PRODURRE UN NUOVO FILE TXT
#funziona anche con catalogoNoHeader (ho tolto con un processsore per pdf
import fitz


CATALOGO = "CatalogoNoHeader.pdf"
OUTPUT_FILE = "output.txt"

#Apre il file output con UTF-8 encoding
with open(OUTPUT_FILE, "w", encoding="utf-8") as file:

    
    #"text" è il parametro per l'OCR
    with fitz.open(CATALOGO) as doc:
        for page in doc:
            text = page.get_text("text")
            
            #Mette nel file
            file.write(text)

# Se funziona conferma 
print( f"funziona {OUTPUT_FILE}")

# %%
import re

# legge il txt come string
with open("output.txt", encoding="UTF-8") as f:
    corpora = f.read()


# toglie spazi, tabs e newline
re.sub('\s{2,}', ' ', corpora)
re.sub('\t+', ' ', corpora)
re.sub('\n+', '', corpora)


# toglie i numeri tra []
txt = re.split(r'\[\d*\s*\w*\s*[^\]]*\]', corpora)
#print(txt)


#splitta la stringa in due prima dell'informazione sul fondo di conservazione
result = []
for book in txt:
    BibInfo = re.split(r'\n(?=BTB)|\n(?=BAC)|\n(?=BAL)|\n(?=BTM)', book)
    
    BibInfo = [i for i in BibInfo if i] # remove empty strings
    #print(BibInfo)
    result.append(BibInfo)
    #print(result)

#toglie la prima list dove c'era VOLUMI ecc
del result[0]
#print(result)



# Extract the first sublists of each list using a list comprehension
#BOOKINFO contains info about the book: author, title, city, publisher and year
BookInfo = [lst[0] for lst in result]
#print(BookInfo)

# Extract the second sublists of each list using a list comprehension
#FUNDINFO CONTAINS THE INFO ABOUT THE CONSERVATION FUND
FundInfo = [sublist[1] for sublist in result if len(sublist) >= 2]
#print(FundInfo)

# %%
#toglie \n prima del nome se c'e
BookInfo = [s.strip() for s in BookInfo]

#print(BookInfo)

# %%
#TOGLIE LE FRASI CONTENTENTI A CURA DI E ANCHE LA FRASE DOPO PERCHE SPESSO E TIPO A. AMBROSINI.

import re


# Remove the sentences containing "A cura di" and the following sentences for each string
pattern = r'[^.]*[Aa]\s*cura\s*di[^.]*\.[^.]*\.'

result = []
for string in BookInfo:
    new_string = re.sub(pattern, '', string)
    result.append(new_string)

#print(result)

BookInfo = result
#print(BookInfo)

# %%
#TOGLIE LE FRASI CONTENTENTI TRADUZIONE DI E ANCHE LA FRASE DOPO PERCHE SPESSO E TIPO A. AMBROSINI.

import re


# Remove the sentences containing "A cura di" and the following sentences for each string
pattern = r'[^.]*[Tt]raduzion[^.]*\.[^.]*\.'

result = []
for string in BookInfo:
    new_string = re.sub(pattern, '', string)
    result.append(new_string)

#print(result)

BookInfo = result
#print(BookInfo)

# %%
#funziona per prendere autori,se c'è un - lo mette nei titoli

#<-----cosi  se c'è - scrive not found
authors = []

for item in BookInfo:
    author = item.split('\n')[0]
    if '-' in author:
        authors.append('Not found')
    else:
        authors.append(author)

#print(authors)
#------>


#cosi invece crea dueliste, una titoli e una autori
#authors = []

#authors = []
#titles =[]
#for item in BookInfo:
    #author = item.split('\n')[0]
    #if '-' in author:
       # titles.append(author)
   # else:
       # authors.append(author)
#print(authors)

# %%
#TOGLIE GLI ASTERISCHI PERCHE ERANO IN MEZZO AI COGLIONI
authors = [x.replace('*', '') for x in authors]

#print(authors)

# %%
# removing whitespace ad inizio e fine stringa
for i in range(len(authors)):
    authors[i] = authors[i].strip()

#print(authors)




#REPLACE ID CON IL NOME CHE LO PRECEDE


for i in range(len(authors)):
    if authors[i] == 'Id.' or authors[i] == 'Id':
        authors[i] = authors[i-1]

#print(authors)

# %%
#toglie i punti dalla lista di autori perchè quando togliebo authors da
#BookInfo toglieva tutti i punti
authorsNoDot = []  # Initialize an empty list to store the modified strings

# Iterate over each string in the 'authors' list
for string in authors:
    updated_string = string.replace(".", "")  # Remove periods from the current string
    authorsNoDot.append(updated_string)  # Append the modified string to the 'updated_strings' list
#print(authorsNoDot)
    
    
    
#toglie gli autori dalla vecchia lista
#toglie da BookInfo gli elementi della lista author 
#e crea una nuova lista TitleInfo con le informazioni rimaste
for i in range(len(BookInfo)):
    for substring in authorsNoDot:
        BookInfo[i] = BookInfo[i].replace(substring, "")
#print(BookInfo)

#TITLEINFO HA TITOLO, CITTA, CE, ANNO, ECC
TitleInfo = BookInfo
#print(TitleInfo)

# %%
#STAMPA LA LISTA DEGLI ANNI
#TOGLIE L'ANNO E IL RESTO DOPO L'ANNO

import re

def remove_after_year(list):
    pattern = r'\b(\d{4})\b'  # Regex pattern to match a 4-digit year surrounded by word boundaries
    years = []  # List to store the extracted years
    
    
    #TOGLIE L'ANNO E IL RESTO DOPO L'ANNO
    # Iterate over each string in the list
    for i in range(len(list)):
        match = re.search(pattern, list[i])  # Find the year match
        if match:
            year = match.group(1)  # Extract the year from the match
            years.append(year)  # Append the year to the years list
            
            year_index = match.start()  # Get the starting index of the year match
            list[i] = list[i][:year_index]  # Keep only the text before the year
    
    return list, years

# Example usage
result, years = remove_after_year(TitleInfo)
#print(result)
#print(years)
result = TitleInfo
#print(TitleInfo)

# %%
#TOGLIE LE \N VUOTE
def remove_newline_followed_by_comma(lst):
    pattern = r'\n,(?=\s*\S)'
    replacement = ','
    modified_lst = []
    for text in lst:
        modified_text = re.sub(pattern, replacement, text)
        modified_lst.append(modified_text.strip())
    return modified_lst

# Example usage
TitleInfo = remove_newline_followed_by_comma(TitleInfo)

#print(TitleInfo)

# %%
# Remove the trailing comma from each string
TitleInfo = [s.rstrip(',') for s in TitleInfo]


#PUBLISHER STANPA LA LISTA DI CASE EDITRICI
publisher = []


#TOGLIE LA CE DALLA STRING DI TITLEINFO
for item in TitleInfo:
    last_part = item.split(",")[-1].strip()  # Extract the last part and remove leading/trailing whitespace
    publisher.append(last_part)

TitleInfo = [item.replace(f", {last_part}", "") for item, last_part in zip(TitleInfo, publisher)]

print(publisher)
#print(TitleInfo)

# %%
cities = []

for i in range(len(TitleInfo)):
    last_period_index = TitleInfo[i].rfind('.')
    if last_period_index != -1:
        city = TitleInfo[i][last_period_index + 1:].strip()
        cities.append(city)
        TitleInfo[i] = TitleInfo[i][:last_period_index].strip()

#print(cities)
# initialize list
test_list = ['gf\ng', 'i\ns', 'b\nest', 'fo\nr', 'geeks\n']

# printing original list
print("The original list : " + str(test_list))

# Removing newline character from string
# using loop
res = []
for sub in test_list:
	res.append(sub.replace("\n", ""))

# printing result
print("List after newline character removal : " + str(res))


#print(BookInfo)
print(title)
# Out:
# ['Ricordi garibaldini', '. \nSomething to read', 'Amici e nemici di Galileo', 'Créatures \nchez \nBalzac', 'Nazionale \ndei \nLincei  \nAdunanza straordinaria pubblica \nRoma 14 novembre', 'L’acquedotto del Flora in Ma- \nremma', 'Le cose migliori', 'Gli ultimi Medici', 'Proust', 'Addestramento della fante-\nria', 'Il tappezziere politico', 'The Advanced Learner’s Dic-\ntionary of Current English', 'Le grandi religioni', 'Antiche fiabe russe', '’700', 'Obsoleto', 'La città di Dio', 'Id.\nLe confessioni', 'Id', 'XVIII settembre MDCCCLX- \nXVIII settembre MDCCCCXII', '75', 'Albert-Sorel', '', '', 'Le prime storie', 'La vita del furfante (', 'Sabbie fiorite', 'Riassunto di geografia fisica e\ngeologia per gli alunni delle scuo-\nle medie superiori', 'Il re buono', 'Haas, Eugen\nCorso completo di lingua tede-\nsca', 'Giornali e lettere scelte', 'Id.\nTragedie', 'Id', 'Enzo\nLucrezio', 'Viaggio in Russia', 'Alge, Sines – Hamburger, So-\nphie – Rippmann, Walter\nLeitfaden für den ersten Unterricht\nim Deutschen (II)', 'Il Convivio', 'Id', 'Id', 'Id.\nLa Divina Commedia giusta la le-\nzione del codice bartoliniano', '* Id.\nLa divina commedia giusta la le-\nzione del codice bartoliniano', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id.\nLe opere. Testo critico della So-\ncietà dantesca italiana.G. Parodi, F. Pellegri-\nni, E. Pistelli, P. Rajna, E', 'Id', 'Id', 'Id', 'Id.\nVita nuova', 'Id', '', 'Alla santa memoria di Car-\nlotta  Gadda Belloni', '* \nLa vie quotidienne sous le Second\nEmpire, Paris', '* \nIntenti politici dei diversi stati\nd’Europa nelle questioni orientali', 'I Musulmani in Sicilia', 'Onoranze centenarie a M', 'Alpinia intimo. Disegni di F', 'Il nipote', 'America d’altri tempi', 'Americana. Raccolta di nar-\nratori dalle origini ai nostri\ngiorni.\nIntroduzione di E. Cecchi. Tra-\nduzioni di G. Ferrata, E. Fulchi-\ngnoni, P. Gadda Conti, C. Li- \nnati, E. Montale, A. Moravia, U.\nMorra, C', '', 'Nizza e l’Italia', 'Civiltà delle lettere', 'Don Giovanni di Volfango Mozart', 'Edouard Manet', 'Louis XIV et l’Europe', 'Un cerchio d’ansia', 'L’italiana in Algeri', 'La vita di Guglielmo Shakespeare', 'L’ultima libertà', '', 'La ricostruzione degli impianti\nidroelettrici sul Velino e sul Nera\ndella Soc', 'Manzoni', 'Id', 'Angioletti, Giovanni Batti-\nsta', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', '* \nStoria d’Italia dal IV al XIX seco-\nlo scritta per le classi liceali', 'Anno bisestile', '', '', '', 'Annuario generale', 'Anonimo (ma C.E. Gadda) \nGli impianti elettrici della Città \ndel Vaticano.\nS.l', 'Vita di Cola di Rienzo', 'Monologio', 'Policleto', 'dai memoriali bolognesi', 'Vita segreta di Gabriele\nD’Annunzio', '* Antologia della poesia ita-\nliana contemporanea', 'contemporanea', 'Antologia della prosa scien-\ntifica italiana del ’600', '', 'contemporanei', 'Alcools: poèmes', 'Id', 'de la jeune fille. s.l', 'L’anonimo lombardo', 'Id', 'Id', 'Id', 'Id', 'Lettere', 'Id', 'Id', 'Id', 'Tosi', 'Opere minori', 'Id.\nOrlando furioso', 'Id.\nOrlando furioso. Vol', 'Id', 'Id', 'Id', 'De arte poetica liber', 'Id', 'Id', 'Id', 'Id', 'Id.\nIl primo libro della metafisica', 'Id', 'Id', 'Essais critiques', '(«Deutsche \nLiteratur', '', 'Id', 'Lavorazione dei metalli', 'Arsa – società anonima carbo-\nnifera', 'remoti ai tempi nostri', 'I minerali', 'Canti', 'Scritti sulla questione della lin-\ngua', 'Lezioni elementari di analisi ma-\ntematica', '', 'per l’agente di campagna\nnelle pratiche operazioni d’agri-\nmensura', 'Atlante Garzanti', '', 'nel triennio', 'durante l’ultimo decennio nel\ncampo delle costruzioni idroe-\nlettriche', 'Napoléon III', 'Id', 'Introduzione alla filologia roman-\nza', 'Id.\nMimesis. Il realismo nella lette-\nratura occidentale. Hinte-\nrhäuser', 'Un augurio a Raffaele Mattio-\nli', '', 'I soliloqui', 'Le vaurien', 'Maometto il conquistatore', 'Acque dolci e peccati', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', '* Id', 'Id', 'Id', 'Id', 'Id', 'Le ma ...

# %%
# Import pandas library
import pandas as pd
  
# initialize list elements
data = list(zip(authors, title, cities, publisher, years))

df = pd.DataFrame(data, columns=['Authors', 'Title', 'Cities', 'Publisher', 'Years'])
display(df)


#df.to_csv('output.csv', index=False, encoding='utf-8')



df.to_csv('output.csv', sep=',', encoding='utf-8')  # Replace ';' with the desired delimiter
